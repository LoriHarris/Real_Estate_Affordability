# %%
import gmaps
import pandas as pd

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Create dataframes
population_df = pd.read_csv('resources/Population_data.csv', encoding='ISO-8859-1')
population_df.head()
# Out:
#    CityName                         Status State(s) 1990Population  \
# 0  Aberdeen  Micropolitan Statistical Area       SD         39,936
# 1  Aberdeen  Micropolitan Statistical Area       WA         64,175
# 2   Abilene  Metropolitan Statistical Area       TX        148,004
# 3       Ada  Micropolitan Statistical Area       OK         34,119
# 4    Adrian  Micropolitan Statistical Area       MI         91,476
#
#   2000Population 2010Population 2017EstPopulation
# 0         39,835         40,602            43,097
# 1         67,141         72,804            72,697
# 2        160,273        165,248           170,219
# 3         35,146         37,492            38,224
# 4         98,970         99,892            98,623

# %%
cities_df = pd.read_csv('resources/cities.csv', encoding='ISO-8859-1')
cities_df.head()
# Out:
#                                CityName  Cloudiness        Date  Humidity  \
# 0  Atlanta - Sandy Springs - Alpharetta          90  1547766900       100
# 1      Austin - Round Rock - Georgetown           1  1547765760        39
# 2         Baltimore - Columbia - Towson          90  1547767380        65
# 3                   Birmingham - Hoover          90  1547766900        92
# 4           Boston - Cambridge - Newton          40  1547765760        33
#
#        Lat      Lng  Max Temp  Wind Speed
# 0  33.7491 -84.3902     46.94        4.70
# 1  30.2711 -97.7437     73.94        3.36
# 2  39.2909 -76.6108     37.04        4.27
# 3  33.5207 -86.8025     50.00        5.82
# 4  42.3603 -71.0583     26.06        5.82

# %%
#merge on city name keeping cities_df "CityName" only
city_pop_df = pd.merge(cities_df, population_df, on="CityName")
city_pop_df
# Out:
#                                              CityName  Cloudiness        Date  \
# 0                Atlanta - Sandy Springs - Alpharetta          90  1547766900
# 1                    Austin - Round Rock - Georgetown           1  1547765760
# 2                       Baltimore - Columbia - Towson          90  1547767380
# 3                                 Birmingham - Hoover          90  1547766900
# 4                         Boston - Cambridge - Newton          40  1547765760
# 5                               Buffalo - Cheektowaga          75  1547766000
# 6                      Charlotte - Concord - Gastonia          90  1547766900
# 7                        Chicago - Naperville - Elgin          90  1547766900
# 8                                          Cincinnati          90  1547766960
# 9                                  Cleveland - Elyria          90  1547767680
# 10                                           Columbus          90  1547766900
# ...

# %%
#drop duplicates keeping one with highest population
