# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
us_city_data_to_load = "Data_files/uscitiesv1.4.csv"
us_city_data = pd.read_csv(us_city_data_to_load)

mort_afford_to_load = "Data_files/TieredAffordability_Mortgage.csv"
mort_afford = pd.read_csv(mort_afford_to_load)

data_data_to_load = "Data_files/BreakEven_PR_2018-03.csv"
data_data = pd.read_csv(data_data_to_load)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb1 in position 5: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-23-234626c0f2f6> in <module>()
#       6
#       7 data_data_to_load = "Data_files/BreakEven_PR_2018-03.csv"
# ----> 8 data_data = pd.read_csv(data_data_to_load)
#
# ...

# %%
us_city_data['citystate'] = us_city_data['city'].map(str) + ", " + us_city_data['state_id']
us_city_data
# Out:
#                  city      city_ascii state_id    state_name  county_fips  \
# 0       Prairie Ridge   Prairie Ridge       WA    Washington        53053
# 1              Edison          Edison       WA    Washington        53057
# 2            Packwood        Packwood       WA    Washington        53041
# 3      Wautauga Beach  Wautauga Beach       WA    Washington        53035
# 4              Harper          Harper       WA    Washington        53035
# 5               Telma           Telma       WA    Washington        53007
# 6            Kahlotus        Kahlotus       WA    Washington        53021
# 7             Mondovi         Mondovi       WA    Washington        53043
# 8           Washtucna       Washtucna       WA    Washington        53001
# 9       Pleasant Hill   Pleasant Hill       WA    Washington        53033
# 10             Toledo          Toledo       WA    Washington        53041
# 11             Wabash          Wabash       WA    Washington        53033
# ...

# %%
city_name = []
density = []
pop_rank= []

# %%
city_list = mort_afford['RegionName'].unique()
city_list
# Out:
# array(['United States', 'Atlanta, GA', 'Austin, TX', 'Baltimore, MD',
#        'Boston, MA', 'Buffalo, NY', 'Charlotte, NC', 'Chicago, IL',
#        'Cincinnati, OH', 'Cleveland, OH', 'Columbus, OH',
#        'Dallas-Fort Worth, TX', 'Denver, CO', 'Detroit, MI',
#        'Hartford, CT', 'Houston, TX', 'Indianapolis, IN',
#        'Jacksonville, FL', 'Kansas City, MO', 'Las Vegas, NV',
#        'Louisville-Jefferson County, KY', 'Memphis, TN',
#        'Miami-Fort Lauderdale, FL', 'Milwaukee, WI',
#        'Minneapolis-St Paul, MN', 'Nashville, TN', 'New Orleans, LA',
#        'New York, NY', 'Oklahoma City, OK', 'Orlando, FL',
#        'Philadelphia, PA', 'Phoenix, AZ', 'Pittsburgh, PA',
#        'Portland, OR', 'Providence, RI', 'Raleigh, NC', 'Richmond, VA',
#        'Riverside, CA', 'Sacramento, CA', 'Salt Lake City, UT',
#        'San Antonio, TX', 'San Diego, CA', 'San Francisco, CA',
#        'San Jose, CA', 'Seattle, WA', 'St. Louis, MO', 'Tampa, FL',
# ...

# %%
for x in city_list:
    print(x)
# Out:
# United States
# Atlanta, GA
# Austin, TX
# Baltimore, MD
# Boston, MA
# Buffalo, NY
# Charlotte, NC
# Chicago, IL
# Cincinnati, OH
# Cleveland, OH
# Columbus, OH
# Dallas-Fort Worth, TX
# Denver, CO
# Detroit, MI
# Hartford, CT
# Houston, TX
# Indianapolis, IN
# Jacksonville, FL
# Kansas City, MO
# Las Vegas, NV
# Louisville-Jefferson County, KY
# Memphis, TN
# Miami-Fort Lauderdale, FL
# Milwaukee, WI
# Minneapolis-St Paul, MN
# Nashville, TN
# New Orleans, LA
# New York, NY
# Oklahoma City, OK
# Orlando, FL
# Philadelphia, PA
# Phoenix, AZ
# Pittsburgh, PA
# Portland, OR
# Providence, RI
# Raleigh, NC
# Richmond, VA
# Riverside, CA
# Sacramento, CA
# Salt Lake City, UT
# San Antonio, TX
# San Diego, CA
# San Francisco, CA
# San Jose, CA
# Seattle, WA
# St. Louis, MO
# Tampa, FL
# Virginia Beach, VA
# Washington, DC
# Los Angeles-Long Beach-Anaheim, CA
