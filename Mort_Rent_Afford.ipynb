# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mort_afford_to_load = "Data_files/TieredAffordability_Mortgage.csv"
mort_afford = pd.read_csv(mort_afford_to_load)

rent_afford_to_load = 'Data_files/TieredAffordability_Rental.csv'
rent_afford = pd.read_csv(rent_afford_to_load)

# %%
mort_afford.head()
# Out:
#    RegionID     RegionName  PopRank         tier  1999-06-30  1999-09-30  \
# 0    102001  United States        0  Bottom Tier    0.303985    0.316021
# 1    102001  United States        0  Middle Tier    0.185879    0.193666
# 2    102001  United States        0   Upper Tier    0.152307    0.158555
# 3    394347    Atlanta, GA        9  Bottom Tier    0.264996    0.277413
# 4    394347    Atlanta, GA        9  Middle Tier    0.167756    0.174504
#
#    1999-12-31  2000-03-31  2000-06-30  2000-09-30     ...      2015-03-31  \
# 0    0.323100    0.337265    0.341345    0.331888     ...        0.198006
# 1    0.200559    0.210686    0.213967    0.207215     ...        0.140809
# 2    0.162713    0.170843    0.173628    0.168954     ...        0.112647
# 3    0.285500    0.302071    0.310339    0.305838     ...        0.146732
# 4    0.179830    0.187178    0.189345    0.184558     ...        0.116767
#
#    2015-06-30  2015-09-30  2015-12-31  2016-03-31  2016-06-30  2016-09-30  \
# ...

# %%
#mort_bottom = mort_afford.loc[mort_afford["tier"] == 'Bottom Tier']
mort_bottom.drop("PopRank")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-056b37a3f7e6> in <module>()
#       1 #mort_bottom = mort_afford.loc[mort_afford["tier"] == 'Bottom Tier']
# ----> 2 mort_bottom.drop("PopRank")
#
# ~\anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\anaconda\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
mort_middle = mort_afford.loc[mort_afford["tier"] == 'Middle Tier']
mort_upper = mort_afford.loc[mort_afford["tier"] == 'Upper Tier']

# %%
rent_bottom = rent_afford.loc[rent_afford["ZRITier"] == 'Bottom Tier']
rent_middle = rent_afford.loc[rent_afford["ZRITier"] == 'Middle Tier']
rent_upper = rent_afford.loc[rent_afford["ZRITier"] == 'Upper Tier']

# %%
mort_bottom.head()
# Out:
#     RegionID     RegionName  PopRank         tier  1999-06-30  1999-09-30  \
# 0     102001  United States        0  Bottom Tier    0.303985    0.316021
# 3     394347    Atlanta, GA        9  Bottom Tier    0.264996    0.277413
# 6     394355     Austin, TX       35  Bottom Tier    0.375188    0.391891
# 9     394358  Baltimore, MD       20  Bottom Tier    0.251283    0.256936
# 12    394404     Boston, MA       10  Bottom Tier    0.457025    0.486076
#
#     1999-12-31  2000-03-31  2000-06-30  2000-09-30     ...      2015-03-31  \
# 0     0.323100    0.337265    0.341345    0.331888     ...        0.198006
# 3     0.285500    0.302071    0.310339    0.305838     ...        0.146732
# 6     0.406876    0.430093    0.440501    0.432168     ...        0.250495
# 9     0.258846    0.267081    0.267596    0.257246     ...        0.186537
# 12    0.508945    0.543331    0.561772    0.559315     ...        0.404582
#
# ...

# %%
Cities_list= mort_bottom["RegionName"]

# %%
mort_bottom_columns = ['1999-12-31', '2000-03-31', '2000-06-30', '2000-09-30', '2000-12-31',
       '2001-03-31', '2001-06-30', '2001-09-30', '2001-12-31', '2002-03-31',
       '2002-06-30', '2002-09-30', '2002-12-31', '2003-03-31', '2003-06-30',
       '2003-09-30', '2003-12-31', '2004-03-31', '2004-06-30', '2004-09-30',
       '2004-12-31', '2005-03-31', '2005-06-30', '2005-09-30', '2005-12-31',
       '2006-03-31', '2006-06-30', '2006-09-30', '2006-12-31', '2007-03-31',
       '2007-06-30', '2007-09-30', '2007-12-31', '2008-03-31', '2008-06-30',
       '2008-09-30', '2008-12-31', '2009-03-31', '2009-06-30', '2009-09-30',
       '2009-12-31', '2010-03-31', '2010-06-30', '2010-09-30', '2010-12-31',
       '2011-03-31', '2011-06-30', '2011-09-30', '2011-12-31', '2012-03-31',
       '2012-06-30', '2012-09-30', '2012-12-31', '2013-03-31', '2013-06-30',
       '2013-09-30', '2013-12-31', '2014-03-31', '2014-06-30', '2014-09-30',
       '2014-12-31', '2015-03-31', '2015-06-30', '2015-09-30', '2015-12-31',
       '2016-03-31', '2016-06-30', '2016-09-30', '2016-12-31', '2017-03-31',
       '2017-06-30']

# %%
#Num_cities = np.arange(len(Cities_list))
data = mort_bottom['1999-06-30']
x_axis = np.arange(len(mort_bottom['RegionName']))
plt.figure(figsize=(20,10))
plt.bar(mort_bottom['RegionName'], data)
plt.ylim(0,1)
tick_locations= [value for value in x_axis]
plt.xticks(tick_locations, mort_bottom['RegionName'], rotation= 'vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x197d9a1bd68>,
# ...
#  <a list of 50 Text xticklabel objects>)
