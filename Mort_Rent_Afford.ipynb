# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mort_afford_to_load = "Data_files/TieredAffordability_Mortgage.csv"
mort_afford = pd.read_csv(mort_afford_to_load)

rent_afford_to_load = 'Data_files/TieredAffordability_Rental.csv'
rent_afford = pd.read_csv(rent_afford_to_load)

# %%
mort_afford.head()
# Out:
#    RegionID     RegionName  PopRank         tier  1999-06-30  1999-09-30  \
# 0    102001  United States        0  Bottom Tier    0.303985    0.316021
# 1    102001  United States        0  Middle Tier    0.185879    0.193666
# 2    102001  United States        0   Upper Tier    0.152307    0.158555
# 3    394347    Atlanta, GA        9  Bottom Tier    0.264996    0.277413
# 4    394347    Atlanta, GA        9  Middle Tier    0.167756    0.174504
#
#    1999-12-31  2000-03-31  2000-06-30  2000-09-30     ...      2015-03-31  \
# 0    0.323100    0.337265    0.341345    0.331888     ...        0.198006
# 1    0.200559    0.210686    0.213967    0.207215     ...        0.140809
# 2    0.162713    0.170843    0.173628    0.168954     ...        0.112647
# 3    0.285500    0.302071    0.310339    0.305838     ...        0.146732
# 4    0.179830    0.187178    0.189345    0.184558     ...        0.116767
#
#    2015-06-30  2015-09-30  2015-12-31  2016-03-31  2016-06-30  2016-09-30  \
# ...

# %%
mort_bottom = mort_afford.loc[mort_afford["tier"] == 'Bottom Tier']
mort_middle = mort_afford.loc[mort_afford["tier"] == 'Middle Tier']
mort_upper = mort_afford.loc[mort_afford["tier"] == 'Upper Tier']

# %%
rent_bottom = rent_afford.loc[rent_afford["ZRITier"] == 'Bottom Tier']
rent_middle = rent_afford.loc[rent_afford["ZRITier"] == 'Middle Tier']
rent_upper = rent_afford.loc[rent_afford["ZRITier"] == 'Upper Tier']

# %%
rent_bottom.tail()
# Out:
#      RegionID      ZRITier                          RegionName  2010-12-31  \
# 135    395121  Bottom Tier                       St. Louis, MO    0.545333
# 138    395148  Bottom Tier                           Tampa, FL    0.629630
# 141    395194  Bottom Tier                  Virginia Beach, VA    0.605468
# 144    395209  Bottom Tier                      Washington, DC    0.541818
# 147    753899  Bottom Tier  Los Angeles-Long Beach-Anaheim, CA    1.079045
#
#      2011-03-31  2011-06-30  2011-09-30  2011-12-31  2012-03-31  2012-06-30  \
# 135    0.536000    0.542000    0.538361    0.507097    0.495238    0.494375
# 138    0.625321    0.623273    0.627132    0.625897    0.631963    0.640976
# 141    0.609964    0.626667    0.635534    0.635122    0.631765    0.637241
# 144    0.528716    0.523765    0.538311    0.542687    0.548571    0.558182
# 147    1.053597    1.044817    1.063665    1.049843    1.035393    1.040419
#
# ...

# %%
mort_bottom_data = mort_bottom.iloc[:, 5:(len(mort_bottom.columns))]
dates = mort_bottom_data.columns
mort_bottom_data["City"] = mort_bottom["RegionName"]
mb_city_index = mort_bottom_data.set_index('City')
mb_flipped = mb_city_index.transpose()

plt.figure(figsize=(40,10))
plt.plot(mb_flipped,)
plt.ylim(0,1.5)
plt.xlim(-0.5, 71.75)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), labels= fig_legend)

x_axis = np.arange(len(dates))
tick_locations= [value for value in x_axis]
plt.xticks(tick_locations, dates, rotation='vertical')
plt.title("Bottom Tier Mortgage Affordability")
plt.ylabel("% of Income")
plt.xlabel("Dates")


plt.tight_layout()
plt.savefig("Images/MortAfford_bottomtier.png")
plt.show()

# %%
mort_middle_data = mort_middle.iloc[:, 5:(len(mort_middle.columns))]
dates = mort_middle_data.columns
mort_middle_data["City"] = mort_middle["RegionName"]
mb_city_index = mort_middle_data.set_index('City')
mb_flipped = mb_city_index.transpose()

plt.figure(figsize=(40,10))
plt.plot(mb_flipped,)
plt.ylim(0,1.5)
plt.xlim(-0.5, 71.75)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), labels= fig_legend)

plt.title("Middle Tier Mortgage Affordability")
plt.ylabel("% of Income")
plt.xlabel("Dates")

x_axis = np.arange(len(dates))
tick_locations= [value for value in x_axis]
plt.xticks(tick_locations, dates, rotation='vertical')

plt.tight_layout()
plt.savefig("Images/MortAfford_middleier.png")
plt.show()

# %%
mort_upper_data = mort_upper.iloc[:, 5:(len(mort_upper.columns))]
dates = mort_upper_data.columns
mort_upper_data["City"] = mort_upper["RegionName"]
mb_city_index = mort_upper_data.set_index('City')
mb_flipped = mb_city_index.transpose()

plt.figure(figsize=(40,10))
plt.plot(mb_flipped,)
plt.ylim(0,1.5)
plt.xlim(-0.5, 71.75)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), labels= fig_legend)

plt.title("Upper Tier Mortgage Affordability")
plt.ylabel("% of Income")
plt.xlabel("Dates")

x_axis = np.arange(len(dates))
tick_locations= [value for value in x_axis]
plt.xticks(tick_locations, dates, rotation='vertical')

plt.tight_layout()
plt.savefig("Images/MortAfford_uppertier.png")
plt.show()

# %%
rent_bottom_data = rent_bottom.iloc[:, 5:(len(rent_bottom.columns))]
dates = rent_bottom_data.columns
rent_bottom_data["City"] = rent_bottom["RegionName"]
mb_city_index = rent_bottom_data.set_index('City')
mb_flipped = mb_city_index.transpose()

plt.figure(figsize=(40,10))
plt.plot(mb_flipped,)
plt.ylim(0,1.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), labels= fig_legend)

plt.title("Bottom Tier Rental Affordability")
plt.ylabel("% of Income")
plt.xlabel("Dates")
plt.xlim(-0.5, 24.5)

x_axis = np.arange(len(dates))
tick_locations= [value for value in x_axis]
plt.xticks(tick_locations, dates, rotation='vertical')

plt.tight_layout()
plt.savefig("Images/RentAfford_Bottomtier.png")
plt.show()

# %%
rent_middle_data = rent_middle.iloc[:, 5:(len(rent_middle.columns))]
dates = rent_middle_data.columns
rent_middle_data["City"] = rent_middle["RegionName"]
mb_city_index = rent_middle_data.set_index('City')
mb_flipped = mb_city_index.transpose()

plt.figure(figsize=(40,10))
plt.plot(mb_flipped,)
plt.ylim(0,1.5)
plt.xlim(-0.5, 24.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), labels= fig_legend)

plt.title("Middle Tier Rental Affordability")
plt.ylabel("% of Income")
plt.xlabel("Dates")

x_axis = np.arange(len(dates))
tick_locations= [value for value in x_axis]
plt.xticks(tick_locations, dates, rotation='vertical')

plt.tight_layout()
plt.savefig("Images/RentAfford_Middletier.png")
plt.show()

# %%
rent_upper_data = rent_upper.iloc[:, 5:(len(rent_upper.columns))]
dates = rent_upper_data.columns
rent_upper_data["City"] = rent_upper["RegionName"]
mb_city_index = rent_upper_data.set_index('City')
mb_flipped = mb_city_index.transpose()

plt.figure(figsize=(40,10))
plt.plot(mb_flipped,)
plt.ylim(0,1.5)
plt.xlim(-0.5, 24.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5), labels= fig_legend)

plt.title("Upper Tier Rental Affordability")
plt.ylabel("% of Income")
plt.xlabel("Dates")

x_axis = np.arange(len(dates))
tick_locations= [value for value in x_axis]
plt.xticks(tick_locations, dates, rotation='vertical')

plt.tight_layout()
plt.savefig("Images/RentAfford_uppertier.png")
plt.show()
