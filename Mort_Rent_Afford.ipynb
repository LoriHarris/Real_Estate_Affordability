# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mort_afford_to_load = "Data_files/TieredAffordability_Mortgage.csv"
mort_afford = pd.read_csv(mort_afford_to_load)

rent_afford_to_load = 'Data_files/TieredAffordability_Rental.csv'
rent_afford = pd.read_csv(rent_afford_to_load)

# %%
rent_afford.head()
# Out:
#    RegionID      ZRITier     RegionName  2010-12-31  2011-03-31  2011-06-30  \
# 0    102001  Bottom Tier  United States    0.652717    0.642292    0.636818
# 1    102001  Middle Tier  United States    0.300364    0.299217    0.298186
# 2    102001   Upper Tier  United States    0.195984    0.192701    0.192000
# 3    394347  Bottom Tier    Atlanta, GA    0.578560    0.566008    0.559375
# 4    394347  Middle Tier    Atlanta, GA    0.263027    0.261335    0.260692
#
#    2011-09-30  2011-12-31  2012-03-31  2012-06-30     ...      2015-03-31  \
# 0    0.637966    0.622921    0.616089    0.618000     ...        0.601358
# 1    0.296529    0.295342    0.294612    0.293842     ...        0.295362
# 2    0.193108    0.190775    0.188988    0.189684     ...        0.188393
# 3    0.554845    0.544898    0.535758    0.532200     ...        0.481055
# 4    0.257331    0.255089    0.253144    0.252605     ...        0.253353
#
# ...

# %%
mort_bottom = mort_afford.loc[mort_afford["tier"] == 'Bottom Tier']

mort_middle = mort_afford.loc[mort_afford["tier"] == 'Middle Tier']

mort_upper = mort_afford.loc[mort_afford["tier"] == 'Upper Tier']

# %%
rent_bottom = rent_afford.loc[rent_afford["ZRITier"] == 'Bottom Tier']
rent_middle = rent_afford.loc[rent_afford["ZRITier"] == 'Middle Tier']
rent_upper = rent_afford.loc[rent_afford["ZRITier"] == 'Upper Tier']

# %%
rent_bottom.head()
# Out:
#     RegionID      ZRITier     RegionName  2010-12-31  2011-03-31  2011-06-30  \
# 0     102001  Bottom Tier  United States    0.652717    0.642292    0.636818
# 3     394347  Bottom Tier    Atlanta, GA    0.578560    0.566008    0.559375
# 6     394355  Bottom Tier     Austin, TX    0.612692    0.608836    0.617465
# 9     394358  Bottom Tier  Baltimore, MD    0.663172    0.665119    0.670270
# 12    394404  Bottom Tier     Boston, MA    0.809714    0.789859    0.775556
#
#     2011-09-30  2011-12-31  2012-03-31  2012-06-30     ...      2015-03-31  \
# 0     0.637966    0.622921    0.616089    0.618000     ...        0.601358
# 3     0.554845    0.544898    0.535758    0.532200     ...        0.481055
# 6     0.614906    0.594771    0.578723    0.580299     ...        0.608425
# 9     0.663545    0.647947    0.638426    0.637922     ...        0.628055
# 12    0.791203    0.779320    0.773064    0.792533     ...        0.777485
#
# ...
